# %%
import pandas as pd

# %%
ExpStocks = pd.read_csv("Expensive Stocks.csv")

# %%
ExpStocks.head()
# Out:
#    S.No.              Name  CMP Rs.  Mar Cap Rs.Cr.  Graham's Number Rs.  \
# 0    1.0      Goblin India    25.95           27.10                49.76
# 1    2.0   Brightcom Group     4.90          248.75               111.26
# 2    3.0          D B Corp    80.85         1414.51               102.46
# 3    4.0      GMM Pfaudler  3814.55         5575.92               562.71
# 4    5.0  Chemcon Special.   418.30         1532.26                  NaN
#
#    Piotski Scr  Face value Rs.  CMP Upside Potential %  52w High Rs.  \
# 0          4.0            10.0                  364.74        120.60
# 1          6.0             2.0                  165.71         13.02
# 2          5.0            10.0                   86.52        150.80
# 3          6.0             2.0                   81.25       6913.85
# 4          4.0            10.0                   77.81        743.80
#
#    QoQ Profits %  Qtr Profit Var %  Profit Var 3Yrs %    P/E  Trd Qty  \
# ...

# %%
ExpStocks.Name
# Out:
# 0          Goblin India
# 1       Brightcom Group
# 2              D B Corp
# 3          GMM Pfaudler
# 4      Chemcon Special.
#              ...
# 280      Vaibhav Global
# 281       Titan Company
# 282    Dixon Technolog.
# 283    Indian Energy Ex
# 284    Kajaria Ceramics
# Name: Name, Length: 285, dtype: object
